# %%
from PIL import Image
from matplotlib import pyplot as plt
from collections import Counter
from scipy import ndimage as ndi
from skimage import feature
import scipy.misc
import numpy as np
import statistics
import random
import scipy
import time
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
from PIL import Image

def open_img(img):
    route = ("C:/Users/Alienware/Downloads/" + img)
    img = Image.open(route)
    img.show()


open_img("daniel.png")

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %matplotlib inline

plt.rcParams["figure.figsize"] = [10,5]

# %%
img = cv2.imread("C:/Users/Alienware/Downloads/daniel.png")
print("size of image", img.shape)
# Out:
# size of image (634, 625, 3)

# %%
plt.imshow(img)
plt.show()

# %%
image = cv2.imread('C:/Users/Alienware/Downloads/daniel.png', cv2.IMREAD_COLOR)

plt.figure()
plt.subplot(141)
plt.title('original')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

plt.subplot(142)
plt.title('canal R')
plt.imshow(image[:,:,0], cmap='gray')

plt.subplot(143)
plt.title('canal G')
plt.imshow(image[:,:,1], cmap='gray')

plt.subplot(144)
plt.title('canal B')
plt.imshow(image[:,:,2], cmap='gray')

plt.show()

# %%
import cv2

imaginicialBGR=cv2.imread('C:/Users/Alienware/Downloads/daniel.png')
print(imaginicialBGR.shape)

plt.imshow(cv2.cvtColor(imaginicialBGR,cv2.COLOR_BGR2RGB))
plt.show()
imageRGB=plt.imread('C:/Users/Alienware/Downloads/daniel.png')
print(imageRGB.shape)
plt.imshow(imageRGB)
plt.show()
# Out:
# (634, 625, 3)
# (634, 625, 4)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %matplotlib inline

plt.rcParams['figure.figsize'] = [5,2.5]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 8
#       6 image = cv2.imread(r'', cv2.IMREAD_GRAYSCALE)
#       7 # guardamos profundidad para mostrar
# ----> 8 original_img = image.dtype
#       9 print('profundidad original de color: ', original_img)
#      10 # transformacion de imagen a 16 bits
#
# AttributeError: 'NoneType' object has no attribute 'dtype'
