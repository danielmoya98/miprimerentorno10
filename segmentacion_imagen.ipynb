# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 5]

# Load the image
img_cancerbgr = cv2.imread("C:/Users/Alienware/Downloads/cancer.jpg")

# Check if the image is loaded correctly
if img_cancerbgr is not None:
    # Convert BGR to RGB
    imagen = cv2.cvtColor(img_cancerbgr, cv2.COLOR_BGR2RGB)

    # Display the image
    plt.imshow(imagen)
    plt.axis('off')  # Turn off axis
    plt.show()
else:
    print("Error: Unable to load the image. Please check the file path.")

# %%
#plt.imshow(imagen[10:45,40:65,1])
plt.imshow(imagen[50:65, 20:35, 1])
plt.show()

# %%
#histograma
celula_cancer = imagen[50:65, 20:35, :]
plt.imsave("celula_cancer.jpg", celula_cancer)
celula = plt.imread("celula_cancer.jpg")
color = ("r", "g", "b")
for canal, col in enumerate(color):
    histogram = cv2.calcHist([celula * 255], [canal], None, [256], [0, 256])
    plt.plot(histogram, color=col)
    plt.xlim([0, 256])
plt.show()

# %%
r_celula = celula[:, :, 0] * 255
g_celula = celula[:, :, 1] * 255
b_celula = celula[:, :, 2] * 255

r_celula = r_celula > 200
g_celula = g_celula > 100
b_celula = b_celula > 200

img_fin = np.array(r_celula * g_celula * b_celula * 255, dtype=int)
plt.imshow(img_fin)
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def solarizar(image, umbral):
    img_solarizar = np.where(image < umbral, image, 255 - image)
    return img_solarizar

def posterizar(image, nivel):
    f_nvl = 255 / nivel
    img_poster = np.round(image / f_nvl) * f_nvl
    return img_poster.astype(np.uint8)

imagen = cv2.imread('C:/Users/Alienware/Downloads/libertad.jpg')
img_gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

umbral = 127
img_sol = solarizar(img_gris, umbral)

nivel = 5
img_posterizada = posterizar(img_gris, nivel)

plt.figure(figsize=(20, 35))

plt.subplot(341)
plt.title('VIVA LA LIBERTAD CARAJO')
plt.imshow(imagen, cmap="gray")
plt.axis('off')

plt.subplot(342)
plt.title('Solarizada')
plt.imshow(img_sol, cmap='gray')
plt.axis('off')

plt.subplot(343)
plt.title('Posterizada')
plt.imshow(img_posterizada, cmap='gray')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10,5]
tamanio_img = 100
R = np.ones((tamanio_img,tamanio_img)) * 2
G = np.ones((tamanio_img,tamanio_img)) * 100
B = np.ones((tamanio_img,tamanio_img)) * 145

imagen = np.dstack((R,G,B))
imagen = np.array(imagen,dtype = int)

plt.figure()
plt.title('Imagen Color')
plt.imshow(imagen)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

ima_color = cv2.imread('C:/Users/Alienware/Downloads/libertad.jpg',cv2.COLOR_BGR2RGB)
ima_color_negativo = 255- ima_color


ima = cv2.imread('C:/Users/Alienware/Downloads/libertad.jpg', cv2.IMREAD_GRAYSCALE)


negativo = 255 - ima


plt.figure(figsize=(10, 5))
plt.title('Escala de grises')
plt.imshow(ima, cmap='gray')
plt.axis('off')
plt.show()


plt.figure(figsize=(10, 5))
plt.title('Escala de grises - negativo')
plt.imshow(negativo)
plt.axis('off')
plt.show()

plt.figure(figsize=(10, 5))
plt.title('Escala de grises')
plt.imshow(ima_color)
plt.axis('off')
plt.show()


plt.figure(figsize=(10, 5))
plt.title('RGB - negativo')
plt.imshow(ima_color_negativo)
plt.axis('off')
plt.show()
