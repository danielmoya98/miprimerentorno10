# %% [markdown]
# Ejercicio 1

# %%
import cv2
import matplotlib.pyplot as plt

imagen_bgr=cv2.imread('C:/Users/Alienware/Downloads/imagen1.jpg')

imagen_rgb = cv2.cvtColor(imagen_bgr, cv2.COLOR_BGR2RGB)

plt.figure(figsize = (10,5))

plt.subplot(1,3,1)
plt.imshow(imagen_bgr)
plt.title('Color')
plt.subplot(1,3,2)
plt.title("Imagen recortada")
plt.imshow(imagen_bgr,cmap="gray")
plt.axis()
plt.ylim([800,625])
plt.xlim([680, 850])
plt.show()

# %% [markdown]
# Ejercicio 2

# %%
import numpy as np
import cv2

width, height = 512, 512

image = np.zeros((height, width, 3), dtype=np.uint8)

color_start = (255, 0, 0)  
color_end = (0, 0, 255)   


for i in range(width):
  
    r = int(color_start[0] * (1 - i / width) + color_end[0] * (i / width))
    g = int(color_start[1] * (1 - i / width) + color_end[1] * (i / width))
    b = int(color_start[2] * (1 - i / width) + color_end[2] * (i / width))
    color = (b, g, r)  

   
    cv2.line(image, (i, 0), (i, height), color, 1)


cv2.imshow('Degradado Lineal', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Ejercicio 3

# %%
from PIL import Image, ImageDraw

width = 800  
height = 800 
square_size = 100 


image = Image.new("RGB", (width, height), "white")
draw = ImageDraw.Draw(image)


for i in range(0, width, square_size):
    for j in range(0, height, square_size):
        if (i // square_size + j // square_size) % 2 == 0:
            draw.rectangle([i, j, i + square_size, j + square_size], fill="black")


image.save("tablero_ajedrez.png")


image.show()
